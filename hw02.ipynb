# %% [markdown]
# # Анализ данных на Python
#
# *Алла Тамбовцева*
#
# ## Домашнее задание №2: поиск аномалий (25 баллов)
#
# В качестве решения необходимо:
#
# * загрузить файл с расширением `.ipynb` или файл с расширением `.py` с кодом на [Dropbox](https://www.dropbox.com/request/TlTrKA05lju2HWZTwVkM);
# * перенести ответы на вопросы в [Google-форму](https://forms.gle/TNRDJsSJRkd7AcLR7).
#
# **Важно.** Ответы на вопросы без приведённого и корректно работающего кода Python не засчитываются.
#
# В этом задании вам предлагается поработать с данными о транзакциях по кредитным картам (какие транзакции были признаны мошенническими, а какие – нет), сохранёнными в папке [cards](https://disk.yandex.ru/d/7n3uqy6AzR7NjA). Файлы именные – выберите файл со своим ФИО из папки.
#
# Переменные в файле:
#
# * `distance_from_home`: расстояние от дома до места совершения транзакции;
# * `distance_from_last_transaction`: расстояние от места совершения транзакции до места совершения последней транзакции;
# * `ratio_to_median_purchase_price`: отношение объема транзакции к медианной стоимости покупок;
# * `repeat_retailer`: были ли покупки у этого продавца ранее (1 – да, 0 – нет);
# * `used_pin_number`: использовался ли ПИН-код при покупке (1 – да, 0 – нет);
# * `online_order`: была ли это покупка онлайн (1 – да, 0 – нет);
# * `fraud`: мошенническая операция или нет (1 – да, 0 – нет).
#
#
# Загрузите данные из CSV-файла в датафрейм и выполните следующие задания.
#
# ### Задача 1 (1 балл)
#
# **Вопрос 1. (1 балл)** Запишите, чему равна доля мошеннических операций в данных. Укажите долю с точностью до сотых.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (2 балла)
#
# Оцените модель логистической регрессии, предсказывающую вероятность мошеннической операции в зависимости от следующих факторов (далее – *Модель 1*):
#
# * расстояние от дома до места совершения транзакции;
# * отношение объема транзакции к медианной сумме покупок;
# * были ли покупки у этого продавца ранее.
#
# Оцените модель логистической регрессии, предсказывающую вероятность мошеннической операции в зависимости от следующих факторов (далее – *Модель 2*):
#
# * расстояние от места совершения транзакции до места совершения последней транзакции;
# * отношение объема транзакции к медианной сумме покупок;
# * были ли покупки у этого продавца ранее;
# * использовался ли ПИН-код при оплате.
#
# **Вопрос 2. (1 балл)** Укажите с точностью до сотых коэффициент из выдачи модели 1 при переменной *расстояние от дома до места совершения транзакции*.
#
# **Вопрос 3. (1 балл)** Укажите с точностью до сотых коэффициент из выдачи модели 2 при переменной *отношение объема транзакции к медианной стоимости покупок*.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (4 балла)
#
# Постройте для модели 1 и модели 2 ROC-кривые (две кривые на одном графике вместе с прямой, соответствующей случайному классификатору) и вычислите для каждой модели значение метрики AUC.
#
# **Вопрос 4. (2 балла)** Прикрепите изображение с полученным графиком.
#
# **Вопрос 5. (1 балл)** Укажите с точностью до тысячных значение AUC для модели 1.
#
# **Вопрос 6. (1 балл)** Укажите с точностью до тысячных значение AUC для модели 2.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (7 баллов)
#
# Опираясь на результаты предыдущей задачи, выберите модель с лучшей предсказательной силой и вычислите предельные эффекты независимых переменных на вероятность мошеннической операции для *медианной транзакции*.
#
# **Вопрос 7. (1 балл)** Укажите характеристики медианной транзакции (медианы независимых переменных в модели).
#
# **Вопрос 8. (2 балла)** Укажите, эффекты каких независимых переменных можно считать статистически значимыми, то есть отличными от 0, на уровне значимости 5%. Перечислите их названия (как в выдаче).
#
# **Вопрос 9. (2 балла)** Укажите значение предельного эффекта при переменной *отношение объема транзакции к медианной сумме покупок*. Проинтерпретируйте содержательно это значение, объясните, что оно показывает (интерпретируйте в любом случае, даже если эффект в вашей модели оказался статистически незначимым).
#
# **Вопрос 10. (2 балла)** Укажите значение предельного эффекта при бинарной независимой переменной в выбранной модели. Проинтерпретируйте содержательно это значение, объясните, что оно показывает (интерпретируйте в любом случае, даже если эффект в вашей модели оказался статистически незначимым).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (3 балла)
#
# Выполните классификацию всех транзакций в данных с помощью выбранной модели, приняв пороговое значение вероятности для класса 1 равным базовому значению 0.5.
#
# **Вопрос 11. (1 балл)** Запишите значение точности (*accuracy*) классификации с точностью до сотых.
#
# **Вопрос 12. (1 балл)** Запишите значение чувствительности модели с точностью до сотых.
#
# **Вопрос 13. (1 балл)** Запишите значение специфичности модели с точностью до сотых.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6 (5 баллов)
#
# Задача выявления аномалий (а к ним, в частности, относится и выявление случаев мошенничества) отличается от стандартных задач классификации. Одно из отличий заключается в том, что при выявлении аномалий мы имеем дело со случаем несбалансированных классов – число аномалий обычно сильно меньше числа «нормальных» наблюдений. Поэтому пороговое значение вероятности 0.5 вряд ли приведет к хорошему качеству классификации.
#
# Измените пороговое значение вероятности и повторите классификацию транзакций в данных с использованием обновленного порогового значения.
#
# **Вопрос 14. (2 балла)** Укажите новое пороговое значение и кратко прокомментируйте, почему выбрали его.
#
# **Вопрос 15. (1 балл)** Запишите значение точности (*accuracy*) обновленной классификации с точностью до сотых.
#
# **Вопрос 16. (1 балл)** Запишите обновленное значение чувствительности модели с точностью до сотых.
#
# **Вопрос 17. (1 балл)** Запишите обновленное значение специфичности модели с точностью до сотых.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 7 (3 балла)
#
# **Вопрос 18. (2 балла)** Запишите предсказанное значение вероятности, согласно вашей итоговой модели, для транзакции с *медианными характеристиками*.
#
# **Вопрос 19. (1 балл)** К какому классу (0 – обычная или 1 – мошенническая) будет отнесена такая транзакция?

# %%
### YOUR CODE HERE ###
