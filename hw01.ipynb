# %% [markdown]
# # Анализ данных на Python
#
# *Алла Тамбовцева*
#
# ## Домашнее задание №1: заказы пицц (30 баллов)
#
# В качестве решения необходимо:
#
# * загрузить файл с расширением `.ipynb` или файл с расширением `.py` с кодом на [Dropbox](https://www.dropbox.com/request/0mQE8avbB8T3OWF0ENhj);
# * перенести ответы на вопросы в [Google-форму](https://forms.gle/4HX7HUBk8GZqUxT76).
#
# **Важно.** Ответы на вопросы без приведённого и корректно работающего кода Python не засчитываются.
#
# В задании предполагается использование методов на последовательностях/датафреймах Pandas или массивах NumPy. Неэффективный код с избыточными конструкциями или привлечением сторонних модулей, без которых можно обойтись, будет штрафоваться. Все задачи решаются с помощью методов, обсуждаемых на занятиях или присутствующих явно в основных материалах курса.

# %% [markdown]
# В этом задании вам предлагается поработать с данными о заказах пиццы, сохранёнными в папках [orders](https://disk.yandex.ru/d/6wpWrdQZUUDArg) и [order_details](https://disk.yandex.ru/d/E4cHYl_B0DWy-Q). Файлы именные – файл со своим ФИО из каждой папки.
#
# В CSV-файле из папки `orders` хранится общая информация о заказах пиццы:
#
# * `order_id`: номер заказа;
# * `date`: дата заказа;
# * `time`: время заказа.
#
# В CSV-файле из папки `order_details` хранится более подробная информация о заказах пиццы:
#
# * `order_details_id`: номер записи (одной пиццы в заказе);
# * `order_id`: номер заказа;
# * `pizza_id`: номер пиццы, состоит из её названия (с `_` вместо пробелов) и её размера (`L/M/S/XL/XXL`, после последнего `_`);
# * `quantity`: число пицц с данным номером в заказе.

# %% [markdown]
# ### Задача 1 (2 балла)
#
# Загрузите данные из `orders` и `order_details` в датафреймы, объедините датафреймы по номеру заказа.
#
# <mark>Подсказка:</mark> метод `.merge()`.
#
# #### Вопрос 1
#
# Выберите строку с индексом 234. Сколько пицц в заказе, часть которого описана в выбранной строке?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2 (6 баллов)
#
# Добавьте в датафрейм `full`:
#
# * столбец `pizza_size` с размером пиццы заглавными буквами (значения из `pizza_id` после последнего `_`);
# * столбец `pizza_type` с названием пиццы без указания её размера (значения из `pizza_id` до `_m`, `_l` и проч).
#
# Примеры значений для некоторых заказов:
#
# * название `hawaiian` и размер `M`;
# * название `classic_dlx` и размер `M`;
# * название `five_cheese` и размер `L`.
#
# #### Вопрос 2
#
# Укажите значение `pizza_size` для второй пиццы в заказе №87.
#
# #### Вопрос 3
#
# Укажите значение `pizza_type` для первой пиццы в заказе №87.
#
# #### Вопрос 4
#
# Пиццы какого размера заказывают чаще всего?
#
# #### Вопрос 5
#
# Пиццы какого типа заказывают чаще всего?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3 (2 балла)
#
# Выведите среднее, медианное и максимальное число пицц в заказе.
#
# #### Вопрос 6
#
# Можно ли на основании посчитанных описательных статистик считать, что в выборке значений числа пицц в заказе присутствуют нехарактерные значения? Если да, то это нехарактерно большие или нехарактерно маленькие значения? Обоснуйте свой ответ.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4 (3 балла)
#
# Сохраните значения *общего числа пицц в заказе*.
#
# #### Вопрос 7
#
# Укажите число нетипичных значений в показателе «общее число пицц в заказе» (в терминах классического ящика с усами, где границы типичных значений определяются через 1.5 межквартильных размаха).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5 (1 балл)
#
# Постройте гистограмму для общего числа пицц в заказе.
#
# #### Вопрос 8
#
# Укажите, является ли распределение симметричным/скошенным. Если скошено, то в какую сторону (вправо, влево).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6 (2 балла)
#
# Выберите строки датафрейма, которые соответствуют пиццам с куриным мясом (содержат `ckn` в названии).
#
# #### Вопрос 9
#
# Укажите число заказов с такими пиццами.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 7 (3 балла)
#
# Приведите столбец с временем заказа к типу «дата-время». Создайте столбец `weekday` со значением дня недели (в полном формате, без сокращений).  Формат даты менять не нужно, на первом месте должен стоять год, на втором – месяц, на третьем – день.
#
# #### Вопрос 10
#
# На какой день недели приходится меньше всего заказов?
#
# #### Вопрос 11
#
# В какой день недели чаще всего заказывают гавайские пиццы (`hawaiian`)?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 8 (7 баллов)
#
# Добавьте бинарный столбец `weekend`, где значение 1 соответствует выходным дням (суббота, воскресенье), а значение 0 – будним дням.
#
# #### Вопрос 12
#
# Укажите число заказов в выходной.
#
# #### Вопрос 13
#
# Сравните доли пицц большого размера (XL и XXL), заказанных в будни и выходные. Проверьте, используя подходящий статистический критерий, можно ли считать доли равными (уровень значимости 5% и двустороняя альтернатива). Укажите p-value с точностью до сотых, полученное по результатам проверки гипотезы.
#
# #### Вопрос 14
#
# В продолжение предыдущего вопроса – сделайте вывод относительно нулевой гипотезы.
#
#
# #### Вопрос 15
#
# Укажите три самых популярных типа (начинки) пиццы в будни и в выходные.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 9 (4 балла)
#
# Добавьте в датафрейм `full` столбец `daypart` из следующих значений:
#
# * `"night"`: если время заказа с 00:00:00 до 04:59:59;
# * `"morning"`: если время заказа с 05:00:00 до 11:59:59;
# * `"afternoon"`: если время заказа с 12:00:00 до 17:59:59;
# * `"evening"`: если время заказа с 18:00:00 до 23:59:59.
#
# #### Вопрос 16
#
# Укажите, в какую часть дня заказывают пиццы самого большого размера.
#
# #### Вопрос 17
#
# Укажите, в какую часть дня чаще всего заказывают пиццы.

# %%
### YOUR CODE HERE ###
